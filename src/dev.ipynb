# %%
import pandas as pd
import requests
import time

# %%
import stocklab.database
# Out:
# c:\Users\Atlas\Desktop\Storage\02-Projects\stocklab\src\stocklab\database\config.json
# True

# %%
'https://www.twse.com.tw/rwd/zh/afterTrading/MI_INDEX?date=20040211&type=ALLBUT0999NOTIND&response=json&_=1776515185801'
