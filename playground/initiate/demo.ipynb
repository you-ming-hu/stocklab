# %%
import pathlib
import json
import time

root = pathlib.Path.cwd().parent
with open(root.joinpath('config.json')) as f:
    config = json.load(f)

save_path = root.joinpath(config['data_root_path'])
end_date = '2026/04/29'

cooldown_time = 2

# %% [markdown]
# # 下載上市股票日資料

# %%
import data_download_helper.taiex_stock_entity_ohlcv

finish = False

while not finish:

    try:
        finish = data_download_helper.taiex_stock_entity_ohlcv.download_batch(
            '2004/02/11', end_date, save_path, '1st'
        )
        finish = data_download_helper.taiex_stock_entity_ohlcv.download_batch(
            '2004/02/11', end_date, save_path, '2nd'
        )

    except Exception as err:
        print('some unexpected error occurred')
        print(err)
        print(f'cooldown for {cooldown_time} hrs')
        time.sleep(cooldown_time * 60 *60)

print('Finished')

# %% [markdown]
# # 下載加權指數日資料
