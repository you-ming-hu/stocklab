# %%
import pathlib
import json

root = pathlib.Path.cwd().parent
with open(root.joinpath('config.json')) as f:
    config = json.load(f)

download_root = root.joinpath(config['download_backup_path'])

end_date = '2026/04/30'

cooldown_time = 2
interations = ['1st', '2nd']

# %% [markdown]
# # TWSE  (上市)

# %% [markdown]
# ## Technicals（技術分析）

# %% [markdown]
# ### Individual - price and volume （個股 - 價量）

# %%
# url_0

import scraper.twse.technicals
import scraper.utils

import checker.twse.technicals
import checker.utils

save_path = download_root.joinpath('twse','technicals','stocks','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.twse.technicals.stocks.price_volume.url_0,
        '2004/02/11',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.twse.technicals.stocks.price_volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.twse.technicals.stocks.price_volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Market - price （大盤 - 價）

# %%
# url_0

import scraper.twse.technicals
import scraper.utils

import checker.twse.technicals
import checker.utils

save_path = download_root.joinpath('twse','technicals','market','price','url_0')

while True:

    scraper.utils.download_raw_material(
        scraper.twse.technicals.market.price.url_0,
        '1999/01/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.twse.technicals.market.price.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.twse.technicals.market.price.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Market - volume （大盤 - 量）

# %%
# url_0

import scraper.twse.technicals
import scraper.utils

import checker.twse.technicals
import checker.utils

save_path = download_root.joinpath('twse','technicals','market','volume','url_0')

while True:

    scraper.utils.download_raw_material(
        scraper.twse.technicals.market.volume.url_0,
        '1990/01/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.twse.technicals.market.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.twse.technicals.market.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## Margin and short （融資券）

# %% [markdown]
# ### Individual - volume, Market - volume and value（個股 - 股數 大盤 - 股數,金額）

# %%
# url_0

import scraper.twse.margin_short
import scraper.utils

import checker.twse.margin_short
import checker.utils

save_path = download_root.joinpath('twse','margin_short','all','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.twse.margin_short.all.stocks_volume_market_volume_value.url_0,
        '2001/01/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.twse.margin_short.all.stocks_volume_market_volume_value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.twse.margin_short.all.stocks_volume_market_volume_value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## Short and SBL （融券借券賣出）

# %% [markdown]
# ### Individual - volume （個股 - 股數）

# %%
# url_0

import scraper.twse.short_sbl
import scraper.utils

import checker.twse.short_sbl
import checker.utils

save_path = download_root.joinpath('twse','short_sbl','stocks','volume','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.twse.short_sbl.stocks.volume.url_0,
        '2005/07/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.twse.short_sbl.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.twse.short_sbl.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Individual - value （個股 - 金額）

# %%
# url_0

import scraper.twse.short_sbl
import scraper.utils

import checker.twse.short_sbl
import checker.utils

save_path = download_root.joinpath('twse','short_sbl','stocks','value','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.twse.short_sbl.stocks.value.url_0,
        '2008/09/26',
        end_date,
        save_path,
        interations,
        cooldown_time
    )


    stop = checker.utils.check_raw_material(
        checker.twse.short_sbl.stocks.value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.twse.short_sbl.stocks.value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## Foreign, trust and dealer （三大法人）

# %% [markdown]
# ### Individual - volume （個股 - 股數）

# %%
# url_0

import scraper.twse.institution_flow
import scraper.utils

import checker.twse.institution_flow
import checker.utils

save_path = download_root.joinpath('twse','institution_flow','stocks','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.twse.institution_flow.stocks.volume.url_0,
        '2012/05/02',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.twse.institution_flow.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.twse.institution_flow.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Market - value （大盤 - 金額）

# %%
# url_0

import scraper.twse.institution_flow
import scraper.utils

import checker.twse.institution_flow
import checker.utils

save_path = download_root.joinpath('twse','institution_flow','market','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.twse.institution_flow.market.value.url_0,
        '2004/04/07',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.twse.institution_flow.market.value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.twse.institution_flow.market.value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## Foreign shareholding （外資持股比例）

# %% [markdown]
# ### Individual volume（個股 - 股數）

# %%
# url_0

import scraper.twse.foreign_shareholding
import scraper.utils

import checker.twse.foreign_shareholding
import checker.utils

save_path = download_root.joinpath('twse','foreign_shareholding','stocks','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.twse.foreign_shareholding.stocks.volume.url_0,
        '2004/02/11',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.twse.foreign_shareholding.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.twse.foreign_shareholding.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# # OTC （上櫃）

# %% [markdown]
# ## Technicals（技術分析）

# %% [markdown]
# ### Individual - price and volume （個股 - 價量）

# %%
# url_0

import scraper.otc.technicals
import scraper.utils

import checker.otc.technicals
import checker.utils

save_path = download_root.joinpath('otc','technicals','stocks','url_0')

while True:

    scraper.utils.download_raw_material(
        scraper.otc.technicals.stocks.price_volume.url_0,
        '2003/08/01', # Taiwn 92
        '2006/12/29', # Taiwan 95
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.technicals.stocks.price_volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.technicals.stocks.price_volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %%
# url_1

import scraper.otc.technicals
import scraper.utils

import checker.otc.technicals
import checker.utils

save_path = download_root.joinpath('otc','technicals','stocks','url_1')

while True:

    scraper.utils.download_raw_material(
        scraper.otc.technicals.stocks.price_volume.url_1,
        '2007/01/01',
        '2007/04/20',
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.technicals.stocks.price_volume.url_1,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.technicals.stocks.price_volume.url_1,
        save_path,
        interations[0],
        interations[1]
    )

# %%
# url_2

import scraper.otc.technicals
import scraper.utils

import checker.otc.technicals
import checker.utils

save_path = download_root.joinpath('otc','technicals','stocks','url_2')

while True:

    scraper.utils.download_raw_material(
        scraper.otc.technicals.stocks.price_volume.url_2,
        '2007/04/21',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.technicals.stocks.price_volume.url_2,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.technicals.stocks.price_volume.url_2,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Market - price （大盤 - 價）

# %%
# url_0

import scraper.otc.technicals
import scraper.utils

import checker.otc.technicals
import checker.utils

save_path = download_root.joinpath('otc','technicals','market','price','url_0')

while True:

    scraper.utils.download_raw_material(
        scraper.otc.technicals.market.price.url_0,
        '1999/09/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.technicals.market.price.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.technicals.market.price.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Market - volume （大盤 - 量）

# %%
# url_0

import scraper.otc.technicals
import scraper.utils

import checker.otc.technicals
import checker.utils

save_path = download_root.joinpath('otc','technicals','market','volume','url_0')

while True:

    scraper.utils.download_raw_material(
        scraper.otc.technicals.market.volume.url_0,
        '1999/01/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.technicals.market.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.technicals.market.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## Margin and short （融資券）

# %% [markdown]
# ### Individual - volume, Market - volume and value（個股 - 股數 大盤 - 股數,金額）

# %%
# url_0

import scraper.otc.margin_short
import scraper.utils

import checker.otc.margin_short
import checker.utils

save_path = download_root.joinpath('otc','margin_short','all', 'url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.margin_short.all.stocks_volume_market_volume_value.url_0,
        '2003/08/01',
        '2006/12/29',
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.margin_short.all.stocks_volume_market_volume_value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.margin_short.all.stocks_volume_market_volume_value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %%
# url_1

import scraper.otc.margin_short
import scraper.utils

import checker.otc.margin_short
import checker.utils

save_path = download_root.joinpath('otc','margin_short','all', 'url_1')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.margin_short.all.stocks_volume_market_volume_value.url_1,
        '2007/01/02',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.margin_short.all.stocks_volume_market_volume_value.url_1,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.margin_short.all.stocks_volume_market_volume_value.url_1,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## Short and SBL （融券借券賣出）

# %% [markdown]
# ### Individual - volume （個股 - 股數）

# %%
# url_0

import scraper.otc.short_sbl
import scraper.utils

import checker.otc.short_sbl
import checker.utils

save_path = download_root.joinpath('otc','short_sbl','stocks','volume','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.short_sbl.stocks.volume.url_0,
        '2006/01/02',
        '2012/03/16',
        save_path,
        interations,
        cooldown_time
    )


    stop = checker.utils.check_raw_material(
        checker.otc.short_sbl.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.short_sbl.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %%
# url_1

import scraper.otc.short_sbl
import scraper.utils

import checker.otc.short_sbl
import checker.utils

save_path = download_root.joinpath('otc','short_sbl','stocks','volume','url_1')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.short_sbl.stocks.volume.url_1,
        '2012/03/19',
        '2012/10/01',
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.short_sbl.stocks.volume.url_1,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.short_sbl.stocks.volume.url_1,
        save_path,
        interations[0],
        interations[1]
    )

# %%
# url_2

import scraper.otc.short_sbl
import scraper.utils

import checker.otc.short_sbl
import checker.utils

save_path = download_root.joinpath('otc','short_sbl','stocks','volume','url_2')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.short_sbl.stocks.volume.url_2,
        '2012/10/02',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.short_sbl.stocks.volume.url_2,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.short_sbl.stocks.volume.url_2,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Individual - value （個股 - 金額）

# %%
# url_0

import scraper.otc.short_sbl
import scraper.utils

import checker.otc.short_sbl
import checker.utils

save_path = download_root.joinpath('otc','short_sbl','stocks','value','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.short_sbl.stocks.value.url_0,
        '2008/10/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.short_sbl.stocks.value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.short_sbl.stocks.value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## Foreign, trust and dealer （三大法人）

# %% [markdown]
# ### Individual - volume （個股 - 股數）

# %%
# url_0

import scraper.otc.institution_flow
import scraper.utils

import checker.otc.institution_flow
import checker.utils

save_path = download_root.joinpath('otc','institution_flow','stocks','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.institution_flow.stocks.volume.url_0,
        '2007/04/21',
        '2014/11/28',
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.institution_flow.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.institution_flow.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %%
# url_1

import scraper.otc.institution_flow
import scraper.utils

import checker.otc.institution_flow
import checker.utils

save_path = download_root.joinpath('otc','institution_flow','stocks','url_1')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.institution_flow.stocks.volume.url_1,
        '2014/12/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.institution_flow.stocks.volume.url_1,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.institution_flow.stocks.volume.url_1,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Market - value （大盤 - 金額）

# %%
# url_0

import scraper.otc.institution_flow
import scraper.utils

import checker.otc.institution_flow
import checker.utils

save_path = download_root.joinpath('otc','institution_flow','market','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.institution_flow.market.value.url_0,
        '2004/06/01',
        '2006/12/29',
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.institution_flow.market.value.url_0,
        save_path,
        interations[0],
        interations[1]
    )


    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.institution_flow.market.value.url_0,
        save_path,
        interations[0],
        interations[1]
    )

# %%
# url_1

import scraper.otc.institution_flow
import scraper.utils

import checker.otc.institution_flow
import checker.utils

save_path = download_root.joinpath('otc','institution_flow','market','url_1')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.institution_flow.market.value.url_1,
        '2007/01/02',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.institution_flow.market.value.url_1,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.institution_flow.market.value.url_1,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## Foreign shareholding （外資持股比例）

# %% [markdown]
# ### Individual volume（個股 - 股數）

# %%
# url_0

import scraper.otc.foreign_shareholding
import scraper.utils

import checker.otc.foreign_shareholding
import checker.utils

save_path = download_root.joinpath('otc','foreign_shareholding','stocks','url_0')

while True:
    scraper.utils.download_raw_material(
        scraper.otc.foreign_shareholding.stocks.volume.url_0,
        '2004/08/04',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.otc.foreign_shareholding.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.otc.foreign_shareholding.stocks.volume.url_0,
        save_path,
        interations[0],
        interations[1]
    )
