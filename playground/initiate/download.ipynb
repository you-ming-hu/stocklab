# %%
import pathlib
import json

root = pathlib.Path.cwd().parent
with open(root.joinpath('config.json')) as f:
    config = json.load(f)

init_root = root.joinpath(config['init_root_path'])

end_date = '2026/04/30'

cooldown_time = 2
interations = ['1st', '2nd']

# %% [markdown]
# # Technicals information (技術面 - 價量)

# %% [markdown]
# ## TWSE (上市)

# %% [markdown]
# ### Individual stocks (個股)

# %%
import scraper.technicals.twse
import scraper.utils

import checker.technicals.twse
import checker.utils

save_path = init_root.joinpath('technicals','TWSE','stocks')

while True:
    scraper.utils.download_raw_material(
        scraper.technicals.twse.stocks,
        '2004/02/11',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.technicals.twse.stocks,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.technicals.twse.stocks,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Market (總體市場)

# %%
import scraper.technicals.twse
import scraper.utils

import checker.technicals.twse
import checker.utils

save_path = init_root.joinpath('technicals','TWSE','market', 'volume')

while True:

    scraper.utils.download_raw_material(
        scraper.technicals.twse.market_volume,
        '1990/01/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.technicals.twse.market_volume,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.technicals.twse.market_volume,
        save_path,
        interations[0],
        interations[1]
    )

# %%
import scraper.technicals.twse
import scraper.utils

import checker.technicals.twse
import checker.utils

save_path = init_root.joinpath('technicals','TWSE','market', 'price')

while True:

    scraper.utils.download_raw_material(
        scraper.technicals.twse.market_price,
        '1999/01/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.technicals.twse.market_price,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.technicals.twse.market_price,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## OTC (上櫃)

# %% [markdown]
# ### Individual stocks (個股)

# %%
# stage 1

import scraper.technicals.otc
import scraper.utils

import checker.technicals.otc
import checker.utils

save_path = init_root.joinpath('technicals', 'OTC','stocks','stage1')

while True:

    scraper.utils.download_raw_material(
        scraper.technicals.otc.stocks_stage_1,
        '2003/08/01', # Taiwn 92
        '2006/12/29', # Taiwan 95
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.technicals.otc.stocks_stage_1,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.technicals.otc.stocks_stage_1,
        save_path,
        interations[0],
        interations[1]
    )

# %%
# stage 2

import scraper.technicals.otc
import scraper.utils

import checker.technicals.otc
import checker.utils

save_path = init_root.joinpath('technicals', 'OTC','stocks','stage2')

while True:

    scraper.utils.download_raw_material(
        scraper.technicals.otc.stocks_stage_2,
        '2007/01/01',
        '2007/04/20',
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.technicals.otc.stocks_stage_2,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.technicals.otc.stocks_stage_2,
        save_path,
        interations[0],
        interations[1]
    )

# %%
# stage 3

import scraper.technicals.otc
import scraper.utils

import checker.technicals.otc
import checker.utils

save_path = init_root.joinpath('technicals', 'OTC','stocks','stage3')

while True:

    scraper.utils.download_raw_material(
        scraper.technicals.otc.stocks_stage_3,
        '2007/04/21',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.technicals.otc.stocks_stage_3,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.technicals.otc.stocks_stage_3,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# # Margin, short, SBL inforamtion (籌碼面 - 融資券)

# %% [markdown]
# ## TWSE (上市)

# %% [markdown]
# ### Short, SBL - individual stocks and market (融券、借券賣出 - 個股和大盤)

# %%
import scraper.short_sbl.twse
import scraper.utils

import checker.short_sbl.twse
import checker.utils

save_path = init_root.joinpath('short_sbl','TWSE','stocks')

while True:
    scraper.utils.download_raw_material(
        scraper.short_sbl.twse.stocks,
        '2005/07/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.short_sbl.twse.stocks,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.short_sbl.twse.stocks,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Margin - individual stocks, ETF (融資 - 個股、ETF)

# %%
import scraper.margin_short.twse
import scraper.utils

import checker.margin_short.twse
import checker.utils

save_path = init_root.joinpath('margin_short','TWSE','stocks')

while True:
    scraper.utils.download_raw_material(
        scraper.margin_short.twse.stocks,
        '2001/01/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.margin_short.twse.stocks,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.margin_short.twse.stocks,
        save_path,
        interations[0],
        interations[1]
    )

# %%
import scraper.margin_short.twse
import scraper.utils

import checker.margin_short.twse
import checker.utils

save_path = init_root.joinpath('margin_short','TWSE','etf')

while True:
    scraper.utils.download_raw_material(
        scraper.margin_short.twse.etf,
        '2003/06/27',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.margin_short.twse.etf,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.margin_short.twse.etf,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Margin - market (融資 - 大盤)

# %%
import scraper.margin_short.twse
import scraper.utils

import checker.margin_short.twse
import checker.utils

save_path = init_root.joinpath('margin_short','TWSE','market')

while True:
    scraper.utils.download_raw_material(
        scraper.margin_short.twse.market,
        '2001/01/01',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.margin_short.twse.market,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.margin_short.twse.market,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## OTC (上櫃)

# %% [markdown]
# # Institution flow information (籌碼面-三大法人)

# %% [markdown]
# ## TWSE (上市)

# %% [markdown]
# ### Shares - individual stocks and market (股數 - 個股、大盤)

# %%
import scraper.institution_flow.twse
import scraper.utils

import checker.institution_flow.twse
import checker.utils

save_path = init_root.joinpath('institution_flow','TWSE','stocks')

while True:
    scraper.utils.download_raw_material(
        scraper.institution_flow.twse.stocks,
        '2012/05/02',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.institution_flow.twse.stocks,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.institution_flow.twse.stocks,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ### Amount - market (金額 - 大盤)

# %%
import scraper.institution_flow.twse
import scraper.utils

import checker.institution_flow.twse
import checker.utils

save_path = init_root.joinpath('institution_flow','TWSE','market')

while True:
    scraper.utils.download_raw_material(
        scraper.institution_flow.twse.market,
        '2004/04/07',
        end_date,
        save_path,
        interations,
        cooldown_time
    )

    stop = checker.utils.check_raw_material(
        checker.institution_flow.twse.market,
        save_path,
        interations[0],
        interations[1]
    )

    if stop:
        break

    checker.utils.remove_inconsistent_raw_material(
        checker.institution_flow.twse.market,
        save_path,
        interations[0],
        interations[1]
    )

# %% [markdown]
# ## OTC (上櫃)

# %% [markdown]
# # Ownership inforamtion (籌碼面-持股)

# %% [markdown]
# ## TWSE (上市)

# %% [markdown]
# ### Foreign - invididual stocks (外資及陸資持股 - 個股)

# %%
import scraper.foreign_ownership.twse
import scraper.utils

save_path = init_root.joinpath('foreign_ownership','TWSE','stocks')

scraper.utils.download_raw_material(
    scraper.foreign_ownership.twse.stocks,
    '2004/02/11',
    end_date,
    save_path,
    interations,
    cooldown_time
)

# %% [markdown]
# ## OTC (上櫃)

# %% [markdown]
# ## TWSE and OTC (上市、上櫃)

# %% [markdown]
# ### Shareholding distribution - individual stocks (股權分散表 - 個股)
