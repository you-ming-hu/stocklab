# %%
import saver
import database

import pathlib
import json

root = pathlib.Path.cwd().parent
with open(root.joinpath('config.json')) as f:
    config = json.load(f)

database_path = root.joinpath(config['database_path'])

sql_commander = database.SQLCommander(database_path)

# %%
saver.technicals.twse.stocks.add_source(path)
saver.technicals.twse.stocks.save_bacth(database.SQLCommander)

# %%
df = saver.technicals.twse.stocks.get_df(file)
saver.technicals.twse.stocks.save_df(df, database.SQLCommander, timestamp)
