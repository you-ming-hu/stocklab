# %%
import database

import pathlib
import json

root = pathlib.Path.cwd().parent
with open(root.joinpath('config.json')) as f:
    config = json.load(f)

database_path = root.joinpath(config['database_path'])
saver = database.commander.Saver(database_path)

init_root = root.joinpath(config['init_root_path'])

# %%
source_path = init_root.joinpath('technicals','TWSE','stocks','1st')

item = database.sources.technicals.twse.stocks
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
source_path = init_root.joinpath('technicals','TWSE','market','volume','1st')

item = database.sources.technicals.twse.market_volume
item.add_path(source_path)

with saver.register(item):
    saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
source_path = init_root.joinpath('technicals','TWSE','market','price','1st')

item = database.sources.technicals.twse.market_price
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
source_path = init_root.joinpath('technicals','OTC','stocks','stage1','1st')

item = database.sources.technicals.otc.stocks_stage_1
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
source_path = init_root.joinpath('technicals','OTC','stocks','stage2','1st')

item = database.sources.technicals.otc.stocks_stage_2
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
source_path = init_root.joinpath('technicals','OTC','stocks','stage3','1st')

item = database.sources.technicals.otc.stocks_stage_3
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
source_path = init_root.joinpath('short_sbl','TWSE','stocks','1st')

item = database.sources.short_sbl.twse.stocks_stage_1
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2012/03/18')

item = database.sources.short_sbl.twse.stocks_stage_2
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2012/03/19')

item = database.sources.short_sbl.twse.market_stage_1
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2012/03/18')

item = database.sources.short_sbl.twse.market_stage_2
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2012/03/19')
# Out:
# ['ALTER TABLE twsedaily ADD COLUMN slb_change_ex_sell_shares INTEGER;']
# twsedaily start
# processing: 20050701
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 25
#      21
#      22 with saver.register(item):
#      23     # saver.init_table()
#      24     cmds = saver.update_table()
# ---> 25     saver.update_database(end_date='2012/03/18')
#      26
#      27 item = database.sources.short_sbl.twse.market_stage_2
#      28 item.add_path(source_path)
#
# File ~/Documents/personal/stocklab/playground/initiate/database/commander/saver.py:98, in Saver.update_database(self, start_date, end_date)
#      96 for file in files:
#      97     print(f'processing: {file.stem}')
# ---> 98     df = self.item.get_df(file.name)
#      99     if df is None:
#     100         continue
#
# File ~/Documents/personal/stocklab/playground/initiate/database/sources/base.py:71, in Source.get_df(self, file)
#      69     return None
#      70 else:
# ---> 71     df = self.standardize(content, file.stem)
#      72     return df
#
# File ~/Documents/personal/stocklab/playground/initiate/database/sources/base.py:54, in Source.standardize(self, content, date)
#      53 def standardize(self, content, date):
# ---> 54     df = self.to_df(content)
#      55     if not df is None:
#      56         df = self.keep_interest(df)
#
# File ~/Documents/personal/stocklab/playground/initiate/database/sources/short_sbl/twse.py:129, in MARKET_STAGE_1.to_df(self, content)
#     126 assert len(head_cols) == 14
#     128 data = [content['data'][-1]]
# --> 129 assert data[0] == ''
#     130 assert '合計' in data[1]
#     132 df = pd.DataFrame(columns=head_cols, data=data)
#
# AssertionError:
