# %%
import database

import pathlib
import json

root = pathlib.Path.cwd().parent
with open(root.joinpath('config.json')) as f:
    config = json.load(f)

database_path = root.joinpath(config['database_path'])
saver = database.commander.Saver(database_path)

init_root = root.joinpath(config['init_root_path'])

# %%
source_path = init_root.joinpath('technicals', 'TWSE','stocks', '1st')

item = database.sources.technicals.twse.stocks
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    saver.update_table()
    saver.update_database()
# Out:
# ['CREATE INDEX IF NOT EXISTS idx_date ON stocks (date);']
# stocks start
# processing: 20040211
# processing: 20040212
# processing: 20040213
# processing: 20040214
# processing: 20040215
# processing: 20040216
# processing: 20040217
# processing: 20040218
# processing: 20040219
# processing: 20040220
# processing: 20040221
# processing: 20040222
# processing: 20040223
# processing: 20040224
# processing: 20040225
# processing: 20040226
# processing: 20040227
# processing: 20040228
# processing: 20040229
# processing: 20040301
# processing: 20040302
# processing: 20040303
# processing: 20040304
# processing: 20040305
# processing: 20040306
# processing: 20040307
# processing: 20040308
# processing: 20040309
# processing: 20040310
# processing: 20040311
# processing: 20040312
# processing: 20040313
# processing: 20040314
# processing: 20040315
# processing: 20040316
# processing: 20040317
# processing: 20040318
# processing: 20040319
# processing: 20040320
# processing: 20040321
# processing: 20040322
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 9
#       5
#       6 with saver.register(item):
#       7     # saver.init_table()
#       8     saver.update_table()
# ----> 9     saver.update_database()
#
# File c:\Users\Atlas\Desktop\Storage\02-Projects\stocklab\playground\initiate\database\commander\saver.py:90, in Saver.update_database(self)
#      88     if df is None:
#      89         continue
# ---> 90     self.save_df(df)
#      91 print(f'{self.item.table.__name__} finished')
#
# File c:\Users\Atlas\Desktop\Storage\02-Projects\stocklab\playground\initiate\database\commander\decorators.py:12, in exec_many.<locals>.wrapper(self, *args, **kwargs)
#      10 with self.conn:
#      11     try:
# ---> 12         self.conn.executemany(
#      13             command,
#      14             parameters
#      15         )
#      16     except Exception as err:
#      17         print(command)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\sqlite3\dbapi2.py:63, in register_adapters_and_converters.<locals>.adapt_date(val)
#      58 from warnings import warn
#      60 msg = ("The default {what} is deprecated as of Python 3.12; "
#      61        "see the sqlite3 documentation for suggested replacement recipes")
# ---> 63 def adapt_date(val):
#      64     warn(msg.format(what="date adapter"), DeprecationWarning, stacklevel=2)
#      65     return val.isoformat()
#
# KeyboardInterrupt:

# %%
import pandas as pd

pd.Timestamp.today().date()
# Out:
# datetime.date(2026, 6, 12)

# %%
item.get_df('20040211.json')
# Out:
#        id    name   open   high    low  close    volume  trades   turnover  \
# 0    0001      鴻運   7.70   7.85   7.70   7.70     19000       7     147700
# 1    0015      富邦   6.20   6.20   6.15   6.15    301000      40    1851900
# 2    0029     富邦店   4.95   4.95   4.89   4.89    365000      63    1796740
# 3    0050  元大台灣50  48.50  48.50  48.26  48.37   5264000     686  254721750
# 4    1101      台泥  19.90  19.90  19.10  19.30  44990547    5708  875661311
# ..    ...     ...    ...    ...    ...    ...       ...     ...        ...
# 706  9941      裕融  34.70  35.20  33.70  34.00    982702     275   33758990
# 707  9942      茂順  42.60  42.90  42.30  42.40     64900      40    2758921
# 708  9943     好樂迪  28.00  28.00  26.60  26.70    134342      55    3663158
# 709  9944      新麗  32.40  32.40  31.60  31.70   1744018     509   55596369
# 710  9945     潤泰新   9.70   9.70   8.80   9.00  64013476    5604  598439547
#
#           date market
# 0   2004-02-11   TWSE
# 1   2004-02-11   TWSE
# 2   2004-02-11   TWSE
# 3   2004-02-11   TWSE
# 4   2004-02-11   TWSE
# ..         ...    ...
# 706 2004-02-11   TWSE
# 707 2004-02-11   TWSE
# 708 2004-02-11   TWSE
# 709 2004-02-11   TWSE
# 710 2004-02-11   TWSE
#
# [688 rows x 11 columns]

# %%
import pydantic

test = pydantic.create_model('test', **{'a':(str, None)})

test(a='a')
# Out:
# test(a='a')
