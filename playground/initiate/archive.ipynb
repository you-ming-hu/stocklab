# %%
import database

import pathlib
import json

root = pathlib.Path.cwd().parent
with open(root.joinpath('config.json')) as f:
    config = json.load(f)

database_path = root.joinpath(config['database_path'])
saver = database.commander.Saver(database_path)

init_root = root.joinpath(config['init_root_path'])

# %%
# 上市 個股 價量

## 價量
source_path = init_root.joinpath('twse','technicals','stocks','1st')

item = database.sources.technicals.twse.stocks.price_volume.version_0
item.add_path(source_path)

with saver.register(item):
    saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 個股 價量

## 價量
source_path = init_root.joinpath('otc','technicals','stocks','version0','1st')

item = database.sources.technicals.otc.stocks.price_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

source_path = init_root.joinpath('otc','technicals','stocks','version1','1st')

item = database.sources.technicals.otc.stocks.price_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

source_path = init_root.joinpath('otc','technicals','stocks','version2','1st')

item = database.sources.technicals.otc.stocks.price_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 大盤 價量

## 價
source_path = init_root.joinpath('twse','technicals','market','price','1st')

item = database.sources.technicals.twse.market.price.version_0
item.add_path(source_path)

with saver.register(item):
    cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 量
source_path = init_root.joinpath('twse','technicals','market','volume','1st')

item = database.sources.technicals.twse.market.volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 大盤 價量

## 價
source_path = init_root.joinpath('otc','technicals','market','price','1st')

item = database.sources.technicals.otc.market.price.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 量
### version 0
source_path = init_root.joinpath('otc','technicals','market','volume','1st')

item = database.sources.technicals.otc.market.volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2024/12/01')

item = database.sources.technicals.otc.market.volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2025/01/01')
# Out:
# []
# otcdaily start
# processing: 19990901
# processing: 19991001
# processing: 19991101
# processing: 19991201
# processing: 20000101
# processing: 20000201
# processing: 20000301
# processing: 20000401
# processing: 20000501
# processing: 20000601
# processing: 20000701
# processing: 20000801
# processing: 20000901
# processing: 20001001
# processing: 20001101
# processing: 20001201
# processing: 20010101
# processing: 20010201
# processing: 20010301
# processing: 20010401
# processing: 20010501
# processing: 20010601
# processing: 20010701
# processing: 20010801
# processing: 20010901
# processing: 20011001
# processing: 20011101
# processing: 20011201
# processing: 20020101
# processing: 20020201
# processing: 20020301
# processing: 20020401
# processing: 20020501
# processing: 20020601
# processing: 20020701
# processing: 20020801
# processing: 20020901
# processing: 20021001
# processing: 20021101
# processing: 20021201
# processing: 20030101
# processing: 20030201
# processing: 20030301
# processing: 20030401
# processing: 20030501
# processing: 20030601
# processing: 20030701
# processing: 20030801
# processing: 20030901
# processing: 20031001
# processing: 20031101
# processing: 20031201
# processing: 20040101
# processing: 20040201
# processing: 20040301
# processing: 20040401
# processing: 20040501
# processing: 20040601
# processing: 20040701
# processing: 20040801
# processing: 20040901
# processing: 20041001
# processing: 20041101
# processing: 20041201
# processing: 20050101
# processing: 20050201
# processing: 20050301
# processing: 20050401
# processing: 20050501
# processing: 20050601
# processing: 20050701
# processing: 20050801
# processing: 20050901
# processing: 20051001
# processing: 20051101
# processing: 20051201
# processing: 20060101
# processing: 20060201
# processing: 20060301
# processing: 20060401
# processing: 20060501
# processing: 20060601
# processing: 20060701
# processing: 20060801
# processing: 20060901
# processing: 20061001
# processing: 20061101
# processing: 20061201
# processing: 20070101
# processing: 20070201
# processing: 20070301
# processing: 20070401
# processing: 20070501
# processing: 20070601
# processing: 20070701
# processing: 20070801
# processing: 20070901
# processing: 20071001
# processing: 20071101
# processing: 20071201
# otcdaily start
# processing: 20250101
# processing: 20250201
# processing: 20250301
# processing: 20250401
# processing: 20250501
# processing: 20250601
# processing: 20250701
# processing: 20250801
# processing: 20250901
# processing: 20251001
# processing: 20251101
# processing: 20251201
# processing: 20260101
# processing: 20260201
# processing: 20260301
# processing: 20260401
# otcdaily finished

# %%
# 上市 個股 融資

## 量
source_path = init_root.joinpath('twse','margin_short','all','1st')

item = database.sources.positions.twse.stocks.margin_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 個股 融資

## 量

## version 0
source_path = init_root.joinpath('otc','margin_short','all','version0','1st')

item = database.sources.positions.otc.stocks.margin_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

### version 1
source_path = init_root.joinpath('otc','margin_short','all','version1','1st')

item = database.sources.positions.otc.stocks.margin_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 大盤 融資

## 量 金額
source_path = init_root.joinpath('twse','margin_short','all','1st')

item = database.sources.positions.twse.market.margin_volume_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 大盤 融資

## 量 金額

### version 0
source_path = init_root.joinpath('otc','margin_short','all','version0','1st')

item = database.sources.positions.otc.market.margin_volume_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

### version 1
source_path = init_root.joinpath('otc','margin_short','all','version1','1st')

item = database.sources.positions.otc.market.margin_volume_value.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 個股 融券借券賣出

## 量
source_path = init_root.joinpath('twse','short_sbl','stocks','volume','1st')

item = database.sources.positions.twse.stocks.short_sbl_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2012/03/18')

item = database.sources.positions.twse.stocks.short_sbl_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2012/03/19')

## 金額
source_path = init_root.joinpath('twse','short_sbl','stocks','value','1st')

item = database.sources.positions.twse.stocks.short_sbl_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 大盤 融券借券賣出

## 量
source_path = init_root.joinpath('twse','short_sbl','stocks','volume','1st')

item = database.sources.positions.twse.market.short_sbl_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2012/03/18')

item = database.sources.positions.twse.market.short_sbl_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2012/03/19')

## 金額
source_path = init_root.joinpath('twse','short_sbl','stocks','value','1st')

item = database.sources.positions.twse.market.short_sbl_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 個股 融券借券賣出

# %%
# 上櫃 大盤 融券借券賣出

# %%
# 上市 個股 三大法人

## 流動 量
source_path = init_root.joinpath('twse','institution_flow','stocks','1st')

item = database.sources.participants.twse.stocks.foreign_trust_dealer_flow_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2014/11/30')

item = database.sources.participants.twse.stocks.foreign_trust_dealer_flow_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2014/12/01', end_date='2017/12/17')

item = database.sources.participants.twse.stocks.foreign_trust_dealer_flow_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2017/12/18')

## 餘額 量
source_path = init_root.joinpath('twse','foreign_shareholding','stocks','1st')

item = database.sources.participants.twse.stocks.foreign_balance_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2009/05/03')

item = database.sources.participants.twse.stocks.foreign_balance_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2009/05/04')

# %%
# 上市 大盤 三大法人

## 流動 量
source_path = init_root.joinpath('twse','institution_flow','stocks','1st')

item = database.sources.participants.twse.market.foreign_trust_dealer_flow_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2014/11/30')

item = database.sources.participants.twse.market.foreign_trust_dealer_flow_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2014/12/01', end_date='2017/12/17')

item = database.sources.participants.twse.market.foreign_trust_dealer_flow_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2017/12/18')

## 餘額 量
source_path = init_root.joinpath('twse','foreign_shareholding','stocks','1st')

item = database.sources.participants.twse.market.foreign_balance_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2009/05/03')

item = database.sources.participants.twse.market.foreign_balance_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2009/05/04')

## 流動 金額
source_path = init_root.joinpath('twse','institution_flow','market','1st')

item = database.sources.participants.twse.market.foreign_trust_dealer_flow_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(end_date='2009/05/03')

item = database.sources.participants.twse.market.foreign_trust_dealer_flow_value.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2009/05/04', end_date='2014/11/30')

item = database.sources.participants.twse.market.foreign_trust_dealer_flow_value.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2014/12/01', end_date='2017/12/17')

item = database.sources.participants.twse.market.foreign_trust_dealer_flow_value.version_3
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database(start_date='2017/12/18')
