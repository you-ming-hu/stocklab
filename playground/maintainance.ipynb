# %%
! uv pip install stocklab@git+https://github.com/you-ming-hu/stocklab.git --upgrade
# Out:
# Using Python 3.12.13 environment at: C:\Users\Atlas\Desktop\Storage\02-Projects\stocklab\.venv
# Resolved 11 packages in 2.86s
#    Updating https://github.com/you-ming-hu/stocklab.git (HEAD)
#     Updated https://github.com/you-ming-hu/stocklab.git (66a97131628def944d25266993ecebbed22abd12)
#    Building stocklab @ git+https://github.com/you-ming-hu/stocklab.git@66a97131628def944d25266993ecebbed22abd12
#       Built stocklab @ git+https://github.com/you-ming-hu/stocklab.git@66a97131628def944d25266993ecebbed22abd12
# Prepared 1 package in 7.86s
# Uninstalled 1 package in 6ms
# Installed 1 package in 21ms
#  - stocklab==0.0.0 (from git+https://github.com/you-ming-hu/stocklab.git@220d3b155b3b1ca7af0ea85e00308b8ff5053eda)
#  + stocklab==0.0.1 (from git+https://github.com/you-ming-hu/stocklab.git@66a97131628def944d25266993ecebbed22abd12)

# %%
import stocklab.database
# Out:
# True
