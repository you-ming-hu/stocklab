# %%
from core import database

import pathlib
import json

with open('config.json') as f:
    config = json.load(f)

database_path = pathlib.Path(config['database_path'])
saver = database.commander.Saver(database_path)

download_root = pathlib.Path(config['download_cache_path'])
backup_root = pathlib.Path(config['download_backup_path'])

# %%
# 上市 個股 價量

## 價量
source_path = download_root.joinpath('twse','technicals','stocks','url_0','1st')

item = database.sources.technicals.twse.stocks.price_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 個股 價量

## 價量
source_path = download_root.joinpath('otc','technicals','stocks','url_2','1st')

item = database.sources.technicals.otc.stocks.price_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 大盤 價量

## 價
source_path = download_root.joinpath('twse','technicals','market','price','url_0','1st')

item = database.sources.technicals.twse.market.price.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 量
source_path = download_root.joinpath('twse','technicals','market','volume','url_0','1st')

item = database.sources.technicals.twse.market.volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 大盤 價量

## 價
source_path = download_root.joinpath('otc','technicals','market','price','url_0','1st')

item = database.sources.technicals.otc.market.price.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 量
source_path = download_root.joinpath('otc','technicals','market','volume','url_0','1st')

item = database.sources.technicals.otc.market.volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 個股 融資

## 量
source_path = download_root.joinpath('twse','margin_short','all','url_0','1st')

item = database.sources.positions.twse.stocks.margin_volume.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 個股 融資

## 量
source_path = download_root.joinpath('otc','margin_short','all','url_1','1st')

item = database.sources.positions.otc.stocks.margin_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 大盤 融資

## 量 金額
source_path = download_root.joinpath('twse','margin_short','all','url_0','1st')

item = database.sources.positions.twse.market.margin_volume_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 大盤 融資

## 量 金額
source_path = download_root.joinpath('otc','margin_short','all','url_1','1st')

item = database.sources.positions.otc.market.margin_volume_value.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 個股 融券借券賣出

## 量
source_path = download_root.joinpath('twse','short_sbl','stocks','volume','url_0','1st')

item = database.sources.positions.twse.stocks.short_sbl_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 金額
source_path = download_root.joinpath('twse','short_sbl','stocks','value','url_0','1st')

item = database.sources.positions.twse.stocks.short_sbl_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 大盤 融券借券賣出

## 量
source_path = download_root.joinpath('twse','short_sbl','stocks','volume','url_0','1st')

item = database.sources.positions.twse.market.short_sbl_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 金額
source_path = download_root.joinpath('twse','short_sbl','stocks','value','url_0','1st')

item = database.sources.positions.twse.market.short_sbl_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 個股 融券借券賣出

## 量
source_path = download_root.joinpath('otc','short_sbl','stocks','volume','url_2','1st')

item = database.sources.positions.otc.stocks.short_sbl_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 金額
source_path = download_root.joinpath('otc','short_sbl','stocks','value','url_0','1st')

item = database.sources.positions.otc.stocks.short_sbl_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 大盤 融券借券賣出

## 量
source_path = download_root.joinpath('otc','short_sbl','stocks','volume','url_2','1st')

item = database.sources.positions.otc.market.short_sbl_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 金額
source_path = download_root.joinpath('otc','short_sbl','stocks','value','url_0','1st')

item = database.sources.positions.otc.market.short_sbl_value.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 個股 三大法人

## 流動 量
source_path = download_root.joinpath('twse','institution_flow','stocks','url_0','1st')

item = database.sources.participants.twse.stocks.foreign_trust_dealer_flow_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 餘額 量
source_path = download_root.joinpath('twse','foreign_shareholding','stocks','url_0','1st')

item = database.sources.participants.twse.stocks.foreign_balance_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 大盤 三大法人

## 流動 量
source_path = download_root.joinpath('twse','institution_flow','stocks','url_0','1st')

item = database.sources.participants.twse.market.foreign_trust_dealer_flow_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 餘額 量
source_path = download_root.joinpath('twse','foreign_shareholding','stocks','url_0','1st')

item = database.sources.participants.twse.market.foreign_balance_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 流動 金額
source_path = download_root.joinpath('twse','institution_flow','market','url_0','1st')

item = database.sources.participants.twse.market.foreign_trust_dealer_flow_value.version_3
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 個股 三大法人

## 流動 量
source_path = download_root.joinpath('otc','institution_flow','stocks','url_1','1st')

item = database.sources.participants.otc.stocks.foreign_trust_dealer_flow_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 餘額 量
source_path = download_root.joinpath('otc','foreign_shareholding','stocks','url_0','1st')

item = database.sources.participants.otc.stocks.foreign_balance_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上櫃 大盤 三大法人

## 流動 量
source_path = download_root.joinpath('otc','institution_flow','stocks','url_1','1st')

item = database.sources.participants.otc.market.foreign_trust_dealer_flow_volume.version_2
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 餘額 量
source_path = download_root.joinpath('otc','foreign_shareholding','stocks','url_0','1st')

item = database.sources.participants.otc.market.foreign_balance_volume.version_1
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

## 流動 金額
source_path = download_root.joinpath('otc','institution_flow','market','url_1','1st')

item = database.sources.participants.otc.market.foreign_trust_dealer_flow_value.version_5
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %%
# 上市 公司 總覽
source_path = download_root.joinpath('twse','company','overview','url_0','1st')

item = database.sources.company.twse.overview.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# 上市 公司 財務
source_path = download_root.joinpath('twse','company','overview','url_0','1st')

item = database.sources.company.twse.financial_statement.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()
# Out:
# ['CREATE INDEX IF NOT EXISTS idx_name ON companyinfo (name);']
# companyinfo start
# processing: 20260818
# companyinfo finished
# ['CREATE TABLE financialstatement (\n\tdate TEXT,\n\tid TEXT,\n\tyear INTEGER,\n\tseason INTEGER,\n\tearnings_per_share INTEGER,\n\toperating_revenue INTEGER,\n\toperating_income INTEGER,\n\tnon_operating_income_expenses INTEGER,\n\tnet_income INTEGER,\nPRIMARY KEY (id, date)\n);']
# []
# financialstatement start
# processing: 20260818
# financialstatement finished

# %%
# 上櫃 公司 總覽
source_path = download_root.joinpath('otc','company','overview','url_0','1st')

item = database.sources.company.otc.overview.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# 上櫃 公司 財務
source_path = download_root.joinpath('otc','company','overview','url_0','1st')

item = database.sources.company.otc.financial_statement.version_0
item.add_path(source_path)

with saver.register(item):
    # cmds = saver.init_table()
    cmds = saver.update_table()
    saver.update_database()
# Out:
# ['CREATE INDEX IF NOT EXISTS idx_name ON companyinfo (name);']
# companyinfo start
# processing: 20260818
# companyinfo finished
# []
# financialstatement start
# processing: 20260818
# financialstatement finished

# %%
from core.database.sources.company.industry import version_0 as processor
import pathlib

root = pathlib.Path(
    '/Users/youming/Documents/personal/stocklab/DataHouse/data/cache/otc/company/industry/url_0/1st'
)

name = '20260818'

path = root.joinpath(name)#.with_suffix('.json')

content = processor.open(path)

raw_df = processor.to_df(content)

df = processor.standardize(content, path, True)

df.head(5)
# Out:
#      id involved_industry  theme       date
# 0  1240                其他  農業科技業 2026-08-18
# 1  1259                食品   餐飲連鎖 2026-08-18
# 2  1264                食品    原物料 2026-08-18
# 3  1268                食品   餐飲連鎖 2026-08-18
# 4  1294                食品    原物料 2026-08-18

# %% [markdown]
# # Meta data

# %%
# 休假
source_path = download_root.joinpath('meta','dayoff','url_1','1st')

item = database.sources.meta.day_off.version_1
item.add_path(source_path)

with saver.register(item):
    # saver.init_table()
    cmds = saver.update_table()
    saver.update_database()

# %% [markdown]
# # Company

# %%
source_path = download_root.joinpath('meta','dayoff','url_1','1st')

# %%
for file in download_root.rglob('*'):
    if file.is_dir():
        backup_root.joinpath(file.relative_to(download_root)).mkdir(parents=True, exist_ok=True)

for file in download_root.rglob('*'):
    if not file.is_dir():
        if file.name == 'inconsistent.json':
            file.unlink()
        else:
            file.rename(backup_root.joinpath(file.relative_to(download_root)))

for file in sorted(download_root.rglob('*'), key=lambda x: len(str(x)), reverse=True):
    file.rmdir()
download_root.rmdir()
